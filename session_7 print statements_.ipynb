# %% [markdown]
# # print statements #

# %%
. print staements are used to see the only out puts
. if we dodnt print means its not an error
. we are just not able to see or check the answer

# %%
number=100
print(number)
# Out:
# 100

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\x240\\OneDrive\\Documents\\nareshit\\python sessions'

# %%
n1=100
n2=200
print(100,200)
# Out:
# 100 200

# %%
n3=300
print(n1,n2,n3)
# Out:
# 100 200 300

# %%
n4=('apple')
print(n1,n2,n3,n4)
# Out:
# 100 200 300 apple

# %%
print('n1','n2','n3','n4')
# Out:
# n1 n2 n3 n4

# %%
print(n1,n2,n3,n4)
# Out:
# 100 200 300 apple

# %%
'n1'=100
'n2'=200
'n3'=300
print('n1','n2','n3')
# Out:
#   Cell In[12], line 1
#     'n1'=100
#     ^
# SyntaxError: cannot assign to literal here. Maybe you meant '==' instead of '='?

# %%
n1=100
n2=200
print(n1+n2)
# Out:
# 300

# %%
'n1'=100
print('n1')
# Out:
#   Cell In[22], line 1
#     'n1'=100
#     ^
# SyntaxError: cannot assign to literal here. Maybe you meant '==' instead of '='?

# %%
print('the addition of 100 and 200 is 300')
print('the addition of n1and n2is add')
# Out:
# the addition of 100 and 200 is 300
# the addition of n1and n2is add

# %%
n1=1000
n2=200
add=n1+n2
print('the addition of',n1,'and',n2,'is',add)
# Out:
# the addition of 1000 and 200 is 1200

# %%
n1=2000
n2=3000
n3=7000
add=n1+n2+n3
print('the addition of',n1,'and',n2,'and',n3,'is',add)
# Out:
# the addition of 2000 and 3000 and 7000 is 12000

# %%
# take three variables
n1='krisna'
n2=25
n3='ameenpur'
print('my name krishna,i am 25 years old,and i came from ameenpur')
# Out:
# my name krishna,i am 25 years old,and i came from ameenpur

# %%
n1=100
n2=200
n3=300
n4='apple'
print(n1,n2,n3)
# Out:
# 100 200 300

# %%
print(n4)
# Out:
# apple

# %%
print(n1+n2+n3,n4)
# Out:
# 600 apple

# %%
print('n1','n2',n4,n1-n2,n1+n2+n3)
# Out:
# n1 n2 apple -100 600

# %%
print('n1=',n1,'and','n2=',n2)
# Out:
# n1= 100 and n2= 200

# %%
n1=100
n2=200
add=n1+n2
print('the addition of n1 and n2 is add')
print('the addition of 100 and 200 is n1+n2')
print('the addition of',n1,'and',n2,'is',add)
# Out:
# the addition of n1 and n2 is add
# the addition of 100 and 200 is n1+n2
# the addition of 100 and 200 is 300

# %%
n1='krishna'
n2='venkata'
n3='nepala'
add=n3+n2+n1
print('the addition of',n1,'and',n2,'and',n3,'is',add)
print(n2)
# Out:
# the addition of krishna and venkata and nepala is nepalavenkatakrishna
# venkata

# %%
print(n1)
# Out:
# 100

# %%
n1='krishna'
n2=25
n3='wiseley collage'
n4='mca'
print('my name is',n1,'and i am',n2,' years old and i completed',n4,'in',n3)
# Out:
# my name is krishna and i am 25  years old and i completed mca in wiseley collage

# %% [markdown]
# # format

# %%
n1='nepala venkata krishna'
n2=25
n3='seri lingam pally'
print('my name is {} and i am {} and i am living in {}'.format(n1,n2,n3))
# Out:
# my name is nepala venkata krishna and i am 25 and i am living in seri lingam pally

# %%
n1='krishna'
n2='omkar'
n3='python mentor'
print('hello {} how are you i am {} your {} course lecturer'.format(n1,n2,n3)
# Out:
# hello krishna how are you i am omkar your python mentor course lecturer

# %% [markdown]
# # f-string

# %%
n1=100
n2=200
add=n1+n2
print('the addition of 100 and 200 is 300')  # print statement
print('the addition of {} and {} is {}') # format
print(f'the addition of {n1} and {n2} is {add}') # string
# Out:
# the addition of 100 and 200 is 300
# the addition of {} and {} is {}
# the addition of 100 and 200 is 300

# %%
n1='krishna'
n2=25
n3='wesley collage'
print(f'my name is {n1}and my age is {n2} and i am studying in {n3}')
# Out:
# my name is krishnaand my age is 25 and i am studying in wesley collage

# %%
n1=100
n2=200
add=n1+n2
print('the addition of {}+{} = {}'.format(n1,n2,add))
# Out:
# the addition of 100+200 = 300

# %%
print(f'the addition of {n1}+{n2} ={add}')
# Out:
# the addition of 100+200 =300

# %%
#5x7=35
n1=5
n2=7
f"{n1}x{n2}={n1*n2}"
# Out:
# '5x7=35'

# %% [markdown]
# # end operator

# %%
print(3,end=' ')
print(4,end=' ')
print(5,end=' ')
# Out:
# 3 4 5

# %%
print(3,4,5)
# Out:
# 3 4 5

# %% [markdown]
# # separator

# %%
print(3,4,5,sep='====>')
# Out:
# 3====>4====>5
