# %%
a=10
b=20
c=a+b
c

# %%
number

# %%
a

# %%
krishna

# %%
krishna=100
krishna

# %%
n1=100

# %%
n1 # he is about to run this cell

# %%
n1

# %%
n4=600

# %%
n4

# %%
# code cell indicates squre brackets before cell
# if the square bracket empty means the cell did not run
# whwn we run cell, there is number available in square bracket

# %%
print('good morning')

# %%
import time
time.sleep(5)
print('good morning')

# %%
import time
time.sleep(10)
print('hii krishna')

# %%
#  kernel is white color: idle state
#  kernel is balck color : busy state
#  kernel is red color  :  dead state

# when kernel is busy there is [*] marks appeal in sqaure bracket

# %%
import time
time.sleep(5)
print('good morning')

# %%
b=100
b

# %%
import time
time.sleep(5)
print('good morning')

# %% [markdown]
# b=100
# b

# %%
kernel is white color
code mode === write the  code
mark down mode === information

# %% [markdown]
# # kkrishna

# %% [markdown]
# ## krishna

# %% [markdown]
# ### krishna

# %% [markdown]
# hashis included in headline for the bigger or smaller head lines
# esm +m for continue

# %% [markdown]
# - kernel is white color: idle state
# -  kernel is balck color : busy state
# -  kernel is red color  :  dead state

# %%
-  kernel is white color: idle state
-  kernel is balck color : busy state
-  kernel is red color  :  dead state
# Out:
#   Cell In[7], line 1
#     -  kernel is white color: idle state
#                        ^
# SyntaxError: invalid syntax

# %%
a=10
b=20
c=a+b
print(c)
# Out:
# 30

# %%
b=40
c=60
b+c
# Out:
# 100
