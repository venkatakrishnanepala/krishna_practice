# %%
a=10
a

# %%
a=20
print(a)

# %% [markdown]
# -print is used to see the answers

# %%
a=10
b=20
a 
b

# %%
a=10
b=20
print(a)
print(b)

# %%
a=10
b=20
a,b

# %%
a,b=30
a,b

# %%
a,b=40,50
a,b

# %%
a=40,50
a

# %% [markdown]
# ## variables

# %% [markdown]
# - variables means will change the values also store the values

# %% [markdown]
# number=100
# number=200
# age=15
# are=20

# %%
a=60,70 # two values are assign in to one variable 
# python developers are implemented as this is working
# no isuue
a

# %%
number=100
NUMBER=200
NUMBER

# %%
NUMBER=100
number=200
NUMber=300
NUMber

# %%
number123=400
number123

# %%
123numer=400
123number

# %%
100/0

# %%
a=20
b=20
print(a+b)
print(a/b)

# %%
number=100
NUMBER=200
NUMber=300
num123=400
123number=500
print(number)
print(NUMBER)
PRINT(NUMber)
print(num123)
print(123num)

# %%
number_one=600
number_one

# %%
areaoftriangle=600
areaoftriangle

# %%
area_of_triangle=700
area_of_triangle

# %%
_=600
_

# %% [markdown]
# under scores also works between no any sentences required

# %%
n1=100
n2=n1
n2=

# %%
krishna=100
name=krishna
name

# %%
'hello'

# %% [markdown]
# red variable is string

# %% [markdown]
# blACK IS VARIABLE

# %%
NAME=VIRAT
NAME

# %% [markdown]
# LOICAL ERROR

# %%
NAME= 'VIRAT'
NAME

# %%
if=100
elstrue
false
for
while
print
type
# key words or reserved word they will not use

# %% [markdown]
# # inbiult functions

# %%
print()
len()
sum()
min()
max()

# %%
1={12345]
len()

# %%
print(1)
print()

# %%
max(1)

# %%
min(1)

# %% [markdown]
# # black means variables
# # red means english
# # green means special purpose

# %%
if=100
if
# Out:
#   Cell In[1], line 1
#     if=100
#       ^
# SyntaxError: invalid syntax

# %%
sum=100
sum
# Out:
# 100

# %%
name=rohit
name
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 name=rohit
#       2 name
#
# NameError: name 'rohit' is not defined

# %%
name='rohit'
name
# Out:
# 'rohit'

# %%
dhoni=7
dhoni
# Out:
# 7

# %%
cricket=dhoni
cricket
# Out:
# 7

# %%
- variables can be*8upper case**
    -NUMBER=100
    
- variables can be**lower case**
    -number=200
- varaibles are**case sensitive**
    -NUMBER=300,number=400
- variables can allow **number as suffix**
    -variables123=500
- variables can not allow **number as prefix**
    -123number=800
- variables can not allowed **spl character**
    --number&one=900
- variables can allow only **underscore**
    -number_one=1000
-variables can be**inbulit functions** but not allowed
    -sum=10
