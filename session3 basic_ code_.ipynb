# %%
import os

# %%
os.getcwd
# Out:
# <function nt.getcwd()>

# %%
- when we miss the function brackets it will give two indications
            - **functions**
            - **bound method**

# %%
print()
sum()
max()
min()
len()
type()

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\x240\\OneDrive\\Documents\\nareshit\\python sessions'

# %%
# wap take three numbers and find the average
n1=10
n2=20
n3=30
avg=(n1+n2+n3)/3
avg
# Out:
# 20.0

# %%
pi=3.14
radius=20
area=pi*radius*radius
area
# Out:
# 1256.0

# %%
area=0.5
breadth=2
height=3
area=0.5*breadth*height
print(area)
# Out:
# 3.0

# %%
total_bill_amount=250
tip_amount=50
total_bill_amount= total_bill_amount*tip_amount
print(total_bill_amount)
# Out:
# 12500

# %%
salary=50000
tax_percentage=5
tax=salary*tax_percentage/100
print(tax)
# Out:
# 2500.0

# %%
round
# Out:
# <function round(number, ndigits=None)>

# %%
round(9.98765)
# Out:
# 10

# %%
# 9.98765===10
round(9.98765,2)
# 9.<9><8765>
# Out:
# 9.99

# %%
round(10.546789,3)
# 10.<d1><d2><d3><d4>
# 10.<5><4><6789>
# Out:
# 10.547
