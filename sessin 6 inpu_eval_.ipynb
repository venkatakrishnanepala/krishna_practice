# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\x240\\OneDrive\\Documents\\nareshit\\python sessions'

# %%
input()
# Out:
#  10
# '10'

# %%
a=10

# %%
input('krishna')
# Out:
# krishna krishna
# 'krishna'

# %%
input('enter your name')
# Out:
# enter your name krishna
# 'krishna'

# %%
input('age')
# Out:
# age 25
# '25'

# %%
input('name')
input('age')
input('gender')
# Out:
# name krishna 25 male
# age 25
# gender male
# 'male'

# %%
input('collage name')
input('adress')
input('pincode')
# Out:
# collage name wesley
# adress secundrab
# pincode 502032
# '502032'

# %%
input('glycomet')
input('sugar')
# Out:
# glycomet 500
# sugar medicine
# 'medicine'

# %%
input()
input()
input()
# Out:
#  name
#  age
#  male
# 'male'

# %%
name=input('enter the name')
age=input('enter the age')
gender=input('enter the gender')
print(name)
print(age)
print(gender)
# Out:
# enter the name krishna
# enter the age 24
# enter the gender male
# krishna
# 24
# male

# %%
input()
# Out:
#  pythom
# 'pythom'

# %%
n1='20'
n2='30'
n1+n2
# Out:
# '2030'

# %%
n1=int('20')
n2=int('30')
int(n1+n2)
# Out:
# 50

# %%
n1=100
n2=200
n1=int(input('enter the n1:'))
n2=int(input('enter the n2:'))
n1+n2
# Out:
# enter the n1: 100
# enter the n2: 200
# 300

# %%
eval('10')
# Out:
# 10

# %%
# wap ask the user enter 3 numbers
# find the avg
# ask the user  means : input and keyboardn1=10
n1=10
n2=20
n3=30
avg=(n1+n2+n3)/3
avg
# Out:
# 20.0

# %%
n1=100
n2=200
n3=300
eval=(n1+n2+n3)/3
eval
# Out:
# 200.0

# %%
n1=100
n2=200
n3=300
eval=(n1+n2+n3)/3
eval
# Out:
# 200.0

# %%
input()
input()
input()
# Out:
#  first box
#  second box
#  third box
# 'third box'

# %%
input('whats your name')
# Out:
# whats your name krishna
# 'krishna'

# %%
input('enter the name')
input('enter the city')
input('enter the age')
# Out:
# enter the name krishna
# enter the city hyderabad
# enter the age 25
# '25'

# %%
n1=input('enter the number n1:')
n2=input('enter the number n2:')
n1+n2
# Out:
# enter the number n1: 20
# enter the number n2: 30
# '2030'

# %%
n1=int(input('enter the n1:'))
n2=int(input('enter the n2:'))
(n1+n2)
# Out:
# enter the n1: 20
# enter the n2: 30
# 50

# %%
n1=int(input('enter the n1:'))
n2=float(input('enter the n2:'))
n1+n2
# Out:
# enter the n1: 100
# enter the n2: 100.5
# 200.5

# %% [markdown]
# # eval

# %%
int('10')
# Out:
# 10

# %%
eval('10.5')
# Out:
# 10.5

# %%
 n1=eval(input('enter the n1:'))
n2=eval(input('enter the n2:'))
n1+n2
# Out:
# enter the n1: 100
# enter the n2: 100.5
# 200.5

# %%
n1=eval(input('enter the n1:'))
n2=eval(input('enter the n2:'))
n1+n2
# Out:
# enter the n1: 10.23
# enter the n2: 10.25
# 20.48

# %%
n1=eval(input('enter the n1:'))
n2=eval(input('enter the n2:'))
round(n1+n2)
# Out:
# enter the n1: 100
# enter the n2: 100.75
# 201

# %%
#drawback-1:float
n1=int(input('enter the n1:')) # 100
n2=int(input('enter the n2:')) # 100.5 error
n1+n2
# change
n1=int(input('enter the n1:'))
n2=int(input('enter the n2:'))
n1+n2
############################################
#draw back-2:
n1=int(input('enter the n1:')) # 100
n2=int(input('enter the n2:')) # 200
n1+n2# 300

# %%
n1=eval(input('enter no:'))
n2=eval(input('enter no:'))
n3=n1+n2
int(n3)
# Out:
# enter no: 12
# enter no: 13
# 25

# %%
# wap ask the user enter 3 numbers
# find the avg
# ask the user means:input and keyboard
n1=10
n2=20
n3=30
avg=(n1+n2+n3)/3
avg
# Out:
# 20.0

# %%
n1=eval(input('enter the n1:'))
n2=eval(input('enter the n2:'))
n3=eval(input('enter the n3:'))
avg=(n1+n2+n3)/3
avg
# Out:
# enter the n1: 10
# enter the n2: 20
# enter the n3: 30
# 20.0

# %%
n1=eval(input('enter the n1:'))
n2=eval(input('enter the n2:'))
n3=eval(input('enter the n3:'))
avg=(n1+n2+n3)/3
round(avg,2)
# Out:
# enter the n1: 12.45
# enter the n2: 13.56
# enter the n3: 14.65
# 13.55

# %%
pi=eval(input('enter the pi:'))
radius=eval(input('enter the radius:'))
area=(pi*radius*radius)
area
# Out:
# enter the pi: 3.14
# enter the radius: 20
# 1256.0

# %%
area=eval(input('enter the area:'))
breadth=eval(input('enter the breadth:'))
heighth=eval(input('enter the heighth:'))
area=(area*breadth*heighth)
area
# Out:
# enter the area: 0.5
# enter the breadth: 2
# enter the heighth: 3
# 3.0

# %%
salary=eval(input('enter the salary:'))
tax_percentage=eval(input('enter the tax_percentage:'))
tax=eval(input('enter the tax:'))
total_tax=salary*tax_percentage/tax
total_tax
# Out:
# enter the salary: 50000
# enter the tax_percentage: 5
# enter the tax: 100
# 2500.0

# %%
bill_amount=eval(input('enter the bill amount:'))
tip_amount=eval(input('enter the tip amount:'))
total_amount=bill_amount+tip_amount
total_amount
# Out:
# enter the bill amount: 5000
# enter the tip amount: 50
# 5050

# %%
carrot=eval(input('enter the carrot:'))
tamota=eval(input('enter the tamota:'))
carrot+tamota
# Out:
# enter the carrot: 20
# enter the tamota: 30
# 50
