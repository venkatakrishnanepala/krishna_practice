# %% [markdown]
# ## type cast

# %% [markdown]
# -type cast means convert one data type to another data type
# -like interger to other data type vice versa

# %%
10+20
# Out:
# 30

# %%
'10'+'20'
# Out:
# '1020'

# %% [markdown]
# **integer to other data types**

# %% [markdown]
# - int to float
# -int to string
# -int to boolean

# %%
n1=100
type(n1)
# Out:
# int

# %%
float(n1)
# Out:
# 100.0

# %%
str(n1)
# Out:
# '100'

# %%
bool(n1)
# Out:
# True

# %%
float_n1=float(n1)
type(float_n1),float_n1
# Out:
# (float, 100.0)

# %%
str_n1=str(n1)
type(str_n1),str_n1
# Out:
# (str, '100')

# %%
bool_n1=bool(n1)
type(bool_n1),bool_n1
# Out:
# (bool, True)

# %%
float====decimal
str===quotes
bool====t/f

# %%
float(-100),str(-100),bool(-100)
# Out:
# (-100.0, '-100', True)

# %%
float(0),str(0),bool(0)
# Out:
# (0.0, '0', False)

# %% [markdown]
# **float to other data types**

# %%
int(10.5),str(10.5),bool(10.5)
# Out:
# (10, '10.5', True)

# %%
int(-10.5),str(-10.5),bool(-10.5)
# Out:
# (-10, '-10.5', True)

# %%
int(0.0);str(0.0),bool(0.0)
# Out:
# ('0.0', False)

# %% [markdown]
# **string to other data types**

# %%
int('100.5'),float('100.5'),bool('100.5')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 int('100.5'),float('100.5'),bool('100.5')
#
# ValueError: invalid literal for int() with base 10: '100.5'

# %%
int(10.5)
# Out:
# 10

# %%
int('10')
# Out:
# 10

# %%
int('10.50')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 int('10.50')
#
# ValueError: invalid literal for int() with base 10: '10.50'

# %%
int(10.5) # works
int('10') # works
int('10.5') # fails

float(10)# 10.0
float('10') #10.5
float('10.5)# 10.5

# %%
int('apple'),float('apple'),bool('apple')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 int('apple'),float('apple'),bool('apple')
#
# ValueError: invalid literal for int() with base 10: 'apple'

# %%
bool('apple')
# Out:
# True

# %%
int(100)
# Out:
# 100

# %%
float(100)
# Out:
# 100.0

# %%
bool(100)
# Out:
# True

# %%
str('100')
# Out:
# '100'

# %%
int(10.5)
# Out:
# 10

# %%
float(10.5)
# Out:
# 10.5

# %%
bool(10.5)
# Out:
# True

# %%
str('10.5')
# Out:
# '10.5'

# %%
int(-100)
# Out:
# -100

# %%
float(-100)
# Out:
# -100.0

# %%
bool(-100)
# Out:
# True

# %%
str(-'100.5')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 str(-'100.5')
#
# TypeError: bad operand type for unary -: 'str'

# %%
str('100')
# Out:
# '100'

# %%
int(apple)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 int(apple)
#
# NameError: name 'apple' is not defined

# %%
float(apple)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 float(apple)
#
# NameError: name 'apple' is not defined

# %%
bool(apple)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 bool(apple)
#
# NameError: name 'apple' is not defined

# %%
str('apple')
# Out:
# 'apple'

# %%
bool('apple')
# Out:
# True

# %%
bool(5)
# Out:
# True

# %% [markdown]
# **boolean to other data type**

# %%
int(true) # 1
float(true) # 1.0
str( true) # true
int(false) # 0
float(false)#0.0
str(false) # false
