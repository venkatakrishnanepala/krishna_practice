# %%
names=['ramesh','suresh','satish']
age=[20,22,24]

# i wnat print like
# ramesh has age 20
# suresh has age 22
# satish has age 24

# %%
for i in range(len(names)):
    print(names[i],age[i])
# Out:
# ramesh 20
# suresh 22
# satish 24

# %%
for i in range(len(names)):
    print(f"{names[i]} has age {age[i]}")
# Out:
# ramesh has age 20
# suresh has age 22
# satish has age 24

# %%
for i in range(len(names)):
    print(f'{names[i]} has age {age[i]}')
# Out:
# ramesh has age 20
# suresh has age 22
# satish has age 24

# %%
l1=[10,20,30]
l2=[100,200,300]
op=[]
for i in range(len(l1)):
    op.append(l1[i]+l2[i])
op
# Out:
# [110, 220, 330]

# %% [markdown]
# **zip**

# %%
list(zip(names,age))
# Out:
# [('ramesh', 20), ('suresh', 22), ('satish', 24)]

# %%
for i,j in zip (names,age):
    print(f'{i} has age {j}')
# Out:
# ramesh has age 20
# suresh has age 22
# satish has age 24

# %%
ramesh===20
suresh==22
both are mapping
dictionary
key-value pair
{<key>:<value>}

# %%
names={'ramesh','suresh','sathish'}
age=[20,22,24]
dict1={'ramesh':20,'suresh':22,'sathish':24}
type(dict1)
# Out:
# dict

# %%
dict1={'ramesh':20,'suresh':22,'sathish':24}

# %%
type(dict1)
# Out:
# dict

# %%
dict5={'ramesh':20,'ramesh':22}
dict5
# Out:
# {'ramesh': 22}

# %%
dict2={20:'ramesh',22:'suresh',24:'mahesh'}
dict2
# Out:
# {20: 'ramesh', 22: 'suresh', 24: 'mahesh'}

# %%
dict3={'20':'ramesh','22':'suresh','24':'naresh'}
dict3
# Out:
# {'20': 'ramesh', '22': 'suresh', '24': 'naresh'}

# %%
dict6={'ramesh':20,'ramesh':20}
dict6
# Out:
# {'ramesh': 20}

# %%
dict7={'ramesh':20,'suresh':20}
dict7
# Out:
# {'ramesh': 20, 'suresh': 20}

# %%
dict4={20:20,22:22,24:24}
dict4
# Out:
# {20: 20, 22: 22, 24: 24}

# %%
dict7={'ramesh':20,'suresh':20}
dict7
# Out:
# {'ramesh': 20, 'suresh': 20}

# %%
dict4={20:20,22:22,24:24}
dict4
# Out:
# {20: 20, 22: 22, 24: 24}

# %%
dict8={'ramesh':20,
      20:'suresh',
    'sathish':True,
     False:True}
dict8
# Out:
# {'ramesh': 20, 20: 'suresh', 'sathish': True, False: True}

# %%
dict1={'ramesh':20,'suresh':22,'sathish':24}
len(dict1)
# Out:
# 3

# %%
dict2={20:'ramesh',22:'suresh',24:'mahesh'}
list(dict2)
# Out:
# [20, 22, 24]

# %%
dict3={'20':'ramesh','22':'suresh','24':'naresh'}
min(dict3)
# Out:
# '20'

# %%
dict3={'20':'ramesh','22':'suresh','24':'naresh'}
str(dict3)
# Out:
# "{'20': 'ramesh', '22': 'suresh', '24': 'naresh'}"

# %%
esh',22:'sudict2={20:'ramresh',24:'mahesh'}
str(dict2)
# Out:
# "{20: 'ramesh', 22: 'suresh', 24: 'mahesh'}"

# %%
dict3={'20':'ramesh','22':'suresh','24':'naresh'}
max(dict3)
# Out:
# '24'

# %%
len(dict1)
# Out:
# 3

# %%
max(dict1)
# Out:
# 'suresh'

# %%
min(dict1)
# Out:
# 'ramesh'

# %%
max(dict2),min(dict2)
# Out:
# (24, 20)

# %%
sum(dict2)
# Out:
# 66

# %%
l={'ramesh','suresh','mahesh'}
l{0}
# Out:
#   Cell In[55], line 2
#     l{0}
#      ^
# SyntaxError: invalid syntax

# %%
l=['ramesh','sursh','krishna']
l[0]
# Out:
# 'ramesh'

# %%
l=['ramesh','suresh','mahesh']
'ramesh' in l
'suresh' in l
'mahesh' in l

for i in l:
  print(i)
# Out:
# ramesh
# suresh
# mahesh

# %%
'ramesh' in l
'suresh' in l
'mahesh' in l

for i in l:
  print(i)
# Out:
# ramesh
# suresh
# mahesh

# %%
dict1['ramesh']
# Out:
# 20

# %%
for i in dict7:
    print(i,dict[i])
# Out:
# ramesh dict['ramesh']
# suresh dict['suresh']

# %%
d={'fruits':{'apple':['kashmir']}}
d['fruits']['apple'][0]
# Out:
# 'kashmir'

# %%
d={'fruits':[{'apple':['green apple']}]}
d['fruits'][0]
# Out:
# {'apple': ['green apple']}

# %%
d['fruits'][0]['apple'][0]
# Out:
# 'green apple'

# %%
d={'fruits':[{'apple':[{'kashmir':[{'india':['naresh it']}}]}]]}
d['fruits']
# Out:
#   Cell In[81], line 1
#     d={'fruits':[{'apple':[{'kashmir':[{'india':['naresh it']}}]}]]}
#                                                               ^
# SyntaxError: closing parenthesis '}' does not match opening parenthesis '['

# %%
dir(dict)
# Out:
# ['__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__ior__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__or__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__ror__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'clear',
#  'copy',
#  'fromkeys',
#  'get',
#  'items',
#  'keys',
#  'pop',
#  'popitem',
#  'setdefault',
#  'update',
#  'values']

# %%
d={'fruits':{'apple':['kashmir']}}
d['fruits']['apple'][0]
# Out:
# 'kashmir'

# %%
clear()

# %%
d['fruits']['apple'][0]
# Out:
# 'kashmir'

# %%
clear

# %%
'clear', # clear
 'copy', # copy
 'fromkeys', #?
 'get', # get a particular value based on keys
 'items', # keys values
 'keys', # only keys
 'pop', # remove
 'popitem', # remove
 'setdefault', #?
 'update', # extend
 'values'] # values

# %%
dict1={'ramesh':20,'suresh':22,'sathish':24}
dict1
# Out:
# {'ramesh': 20, 'suresh': 22, 'sathish': 24}

# %%
clear

# %%
dict1
# Out:
# {'ramesh': 20, 'suresh': 22, 'sathish': 24}

# %%
clear(dict1)

# %%
dict1
# Out:
# {'ramesh': 20, 'suresh': 22, 'sathish': 24}

# %%
dict1(copy)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 dict1(copy)
#
# NameError: name 'copy' is not defined

# %%
dict3={'20':'ramesh','22':'suresh','24':'naresh'}
dict3
# Out:
# {'20': 'ramesh', '22': 'suresh', '24': 'naresh'}

# %%
copy(dict3)
# Out:
# The system cannot find the file specified.

# %%
copy
# Out:
# The syntax of the command is incorrect.

# %%
dict3={'20':'ramesh','22':'suresh','24':'naresh'}
dict3
# Out:
# {'20': 'ramesh', '22': 'suresh', '24': 'naresh'}

# %%
remove(dict3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 remove(dict3)
#
# NameError: name 'remove' is not defined

# %%
l=[]
l.append(10)
l
# Out:
# [10]

# %%
d={}
d['ramesh']=20
d
# Out:
# {'ramesh': 20}

# %%
dir({})
# Out:
# ['__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__ior__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__or__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__ror__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'clear',
#  'copy',
#  'fromkeys',
#  'get',
#  'items',
#  'keys',
#  'pop',
#  'popitem',
#  'setdefault',
#  'update',
#  'values']

# %%
d={'ramesh':20}
d['suresh']=25
d
# Out:
# {'ramesh': 20, 'suresh': 25}

# %%
d={'ramesh':20,'suresh':25}
d['suresh']=30
d
# Out:
# {'ramesh': 20, 'suresh': 30}

# %%
d={}
d['venkata krishna']=25
d['rajesh']=27
d
# Out:
# {'venkata krishna': 25, 'rajesh': 27}

# %%
# there are two list we need to make a dict

# %%
names=['ramesh','suresh','sathish']
age=[20,21,22]
d={}
d['ramesh']=20
d['suresh']=21
d['sathish']=22
d
# Out:
# {'ramesh': 20, 'suresh': 21, 'sathish': 22}

# %%
list(zip(names,age))
# Out:
# [('ramesh', 20), ('suresh', 21), ('sathish', 22)]

# %%
names=['ramesh','suresh','sathish']
age=[20,21,22]
d={}
d['ramesh']=20
d['suresh']=21
d['sathish']=22
for i,j in zip(names,age):
    print(f'{i} has {j}')
# Out:
# ramesh has 20
# suresh has 21
# sathish has 22

# %%
for i,j in zip (names,age):
    print(f'{i} has age {j}')
# Out:
# ramesh has age 20
# suresh has age 21
# sathish has age 22

# %%
names=['venkata krishna','rajesh','subba raju']
ages=[25,27,46]
d={}
d['venkata krishna']=25
d['rajesh']=27
d['subba raju']=46
d
# Out:
# {'venkata krishna': 25, 'rajesh': 27, 'subba raju': 46}

# %%
list(zip(names,ages))
# Out:
# [('venkata krishna', 25), ('rajesh', 27), ('subba raju', 46)]

# %%
list(zip(names,ages))
# Out:
# [('venkata krishna', 25), ('rajesh', 27), ('subba raju', 46)]

# %%
for i ,j in zip(names,ages):
    print(f'{i} has age {j}')
# Out:
# venkata krishna has age 25
# rajesh has age 27
# subba raju has age 46

# %%
names=['venkata krishna','rajesh','subba raju']
ages=[25,27,46]
i.append(names)
print(i)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[52], line 3
#       1 names=['venkata krishna','rajesh','subba raju']
#       2 ages=[25,27,46]
# ----> 3 i.append(names)
#       4 print(i)
#
# AttributeError: 'str' object has no attribute 'append'

# %%
d={'ramesh':20,'suresh':22,'sathish':24}
names,age=[],[]
for i in d:
    names.append(i)
    age.append(d[i])
names,age
# Out:
# (['ramesh', 'suresh', 'sathish'], [20, 22, 24])

# %%
d.clear()

# %%
names,age
# Out:
# (['ramesh', 'suresh', 'sathish'], [20, 22, 24])

# %%
dict1.clear()

# %%
dict1
# Out:
# {}

# %%
dict2()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[66], line 1
# ----> 1 dict2()
#
# NameError: name 'dict2' is not defined

# %%
dict5
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[67], line 1
# ----> 1 dict5
#
# NameError: name 'dict5' is not defined

# %%
names,age
# Out:
# (['ramesh', 'suresh', 'sathish'], [20, 22, 24])

# %%
names,age.clear()
# Out:
# (['ramesh', 'suresh', 'sathish'], None)

# %%
names,age
# Out:
# (['ramesh', 'suresh', 'sathish'], [])

# %%
names.clear()

# %%
names,ages
# Out:
# ([], [25, 27, 46])

# %%
dict1={'ramesh':20,'suresh':22,'sathish':24}
dict1
# Out:
# {'ramesh': 20, 'suresh': 22, 'sathish': 24}

# %%
dict1.clear()

# %%
dict1
# Out:
# {}

# %%
str1='hai hw are you'
str1.split()
# Out:
# ['hai', 'hw', 'are', 'you']

# %%
l=['hai','how','are','you']
s1=''
s2='===>'
s3='***'
s1.join(l),s2.join(l),s3.join(l)
# Out:
# ('haihowareyou', 'hai===>how===>are===>you', 'hai***how***are***you')

# %% [markdown]
# **word counter**

# %%
str1='python is easy python i super python is powerfull'
#d={'easy':1,'is':3,'powerfull':1,'python':3,'super':1}
l= sorted(str1.split())
d=[]
for i in l:
    if i in d:
        d[i]+=1
    else:
        d[i]=1
d
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[84], line 9
#       7         d[i]+=1
#       8     else:
# ----> 9         d[i]=1
#      10 d
#
# TypeError: list indices must be integers or slices, not str

# %%
dir(i)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'removeprefix',
# ...

# %%
str1=('python is easy python i super python is powerfull')
l= sorted(str1.split())
d={}
for i in l:
    if i in d:
        d[i]+=1
    else:
        d[i]=1
d
# Out:
# {'easy': 1, 'i': 1, 'is': 2, 'powerfull': 1, 'python': 3, 'super': 1}

# %%
d={'ramesh':20,'sures':21,'sathish':22}
d.keys()
# Out:
# dict_keys(['ramesh', 'sures', 'sathish'])

# %%
# its look like a list but it it is not a key
keys=d.keys()
keys
# Out:
# dict_keys(['ramesh', 'sures', 'sathish'])

# %%
keys=d.keys()
list(keys)
# Out:
# ['ramesh', 'sures', 'sathish']

# %%
l=['a','b','c']
l.index('b')
# Out:
# 1

# %% [markdown]
# **set default**

# %%
d={'ramesh':20,'sures':21,'sathish':22}
d.setdefault('ramesh',30)
d
# Out:
# {'ramesh': 20, 'sures': 21, 'sathish': 22}

# %%
d={'ramesh':20,'sures':21,'sathish':22}
d.setdefault('mahesh',30)
d
# case-1:key is already there
# ramesh has value 20
# Out:
# {'ramesh': 20, 'sures': 21, 'sathish': 22, 'mahesh': 30}

# %%
d1={'ramesh':20,'sures':21,'sathish':22}
#case-2: key is not avaiable
d2={'mahesh':25}
d1.update(d2)
d1
# Out:
# {'ramesh': 20, 'sures': 21, 'sathish': 22, 'mahesh': 25}

# %%
d1={'ramesh':20,'sures':21,'sathish':22}
d['ramesh']=25
d
# Out:
# {'ramesh': 25, 'sures': 21, 'sathish': 22}

# %%
d={'ramesh':20,'sures':21,'sathish':22}
d.setdefault('mahesh',30)('krishna',25)('abhi',22)
d
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[107], line 2
#       1 d={'ramesh':20,'sures':21,'sathish':22}
# ----> 2 d.setdefault('mahesh',30)('krishna',25)('abhi',22)
#       3 d
#
# TypeError: 'int' object is not callable

# %%
d={'ramesh','sures':21,'sathish':22}
d.setdefault('ramesh',30)
d
# Out:
#   Cell In[108], line 1
#     d={'ramesh','sures':21,'sathish':22}
#                        ^
# SyntaxError: invalid syntax

# %%
d={'ramesh':20,'sures':21,'sathish':22}
d.get('ramesh')
d
# Out:
# {'ramesh': 20, 'sures': 21, 'sathish': 22}

# %%
d={'ramesh':20,'sures':21,'sathish':22}
d.get('ramesh')
d['ramesh']
# Out:
# 20

# %%
dictionary mutable
if you able to change the content of any object==mutable
in dictionary we can change value==dictionary effectd==mutable
in dictionary you can not change keys
backend the data store with **hashkeys**
like primary key in sql

# %%
d={}
d.setdefault('DS',[]).append('ramesh')
d.setdefault('DS',[]).append('suresh')
d
# Out:
# {'DS': ['ramesh', 'suresh']}

# %%
id('ramesh')
# Out:
# 2447390203296

# %%
id('venkata krishna')
# Out:
# 2447398860976

# %%
hash('venkata krishna')
# backend on what is the unique id of venkata krishna
# Out:
# -3462712241109994723

# %% [markdown]
# **fromkeys**

# %%
d={}
d1=d.fromkeys(['apple','banana'],'fruits')
d,d1
# Out:
# ({}, {'apple': 'fruits', 'banana': 'fruits'})

# %%
import random
random.fromkeys
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[122], line 2
#       1 import random
# ----> 2 random.fromkeys
#
# AttributeError: module 'random' has no attribute 'fromkeys'

# %%
import random
l=[10,100,200,300,400]
random.choice(l)
random.shuffle(l)
l
# Out:
# [100, 400, 10, 300, 200]
